# %% [markdown]
# <a href="https://colab.research.google.com/github/rishisaini1223/pyhton_codes/blob/main/read_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# When we have to operate any operation on the file then we must have to open that file fisrt.
# syntax of opening a file ->
# f = open('filename','mode')
#
# 'r' -> read mode
#
# file = open('name.txt','r')

# %%
file = open('name.txt','r')
content = file.read()
print(content)

# %%
# for read file
try:
  file = open('nae.txt','r')
except FileNotfounderror:
  print('Please enter the valid file address')
else:
  content = file.read()
  print(content)
finally:
  file.close()
  print('File is closed')

# %%
# for read single line of the file we use readline()
# Readlines -> it return the list of lines.
try:
  file = open('nae.txt','r')
except FileNotfounderror:
  print('Please enter the valid file address')
else:
  content = file.readline()
  print(content)
finally:
  file.close()
  print('File is closed')

# %%
# file.tell() function gives the current location of the file.
