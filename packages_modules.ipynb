# %% [markdown]
# <a href="https://colab.research.google.com/github/rishisaini1223/pyhton_codes/blob/main/packages_modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# packeges and modules

# %% [markdown]
# - modules- modules are the py files which contains some methods ,class and variables.
# - packages - packages are the collection of the modules and that also contain '__init__' py file.

# %%
from math_ops.function import add, sub, mul, div, exp
# for import function from the packages.

# %%
# create a package name result systeam.
# marks.py -> calculate total and percentage.
# grade.py -> assign grade based on percentage.
# report.py -> display formmatted result.

# in the main file.
# import modules form the package.
# generate the final report of the three students.

# %%
# student
class student:
  def __init__(self, name,math,science,ss):
    self.name = name
    self.math = math
    self.science = science
    self.ss = ss

# %%
# marks.py
def total(a,b,c):
  return a+b+c

def percentage(a,b,c):
  return (a+b+c)/300

# %%
# grade.py
from marks import percentage

def assign_grade(per):
  if per > 95:
    return 'a'
  elif 95 >= per > 85:
    return 'b'
  else:
   return 'fail'

# %%
# report.py
# name, total marks, percentage grade
def display(name,total,per, grade):
  print(f'name: {name}')
  print(f'total marks: {total}')
  print(f'percentage: {per}')
  print(f'grade: {grade}')
# Out:
#   File "/tmp/ipython-input-2291193908.py", line 3
#     def display(name,total,per, grade):
#                                        ^
# SyntaxError: incomplete input

# %%
from result_system.report import display
from result_system.grade import assign_grade
from result_system.marks import percentage, total
from result_system.student import student
first = 'rahul'
math = 50
science = 70
ss =  80

total_m = total(math, science, ss)
per = percentage(math, science, ss)
grade = assign_grade(percentage)

display(first,total_m, per, grade)
